# %%
import warnings
warnings.filterwarnings(action='ignore')
from google.colab import drive
drive.mount('/gdrive')

# %%
# !pip install tensorboardX

# %%
import tensorboardX

# %%
# !git clone https://github.com/weepiess/StyleFlow-Content-Fixed-I2I.git

# %%
# !wget -O /content/StyleFlow-Content-Fixed-I2I/wikiart_tv_0.6.ckpt.pth.tar https://drive.google.com/uc?id=1FWX9Ovu8Z8nmz63b3oXfu1poUA-N2HjY

# %%
ls /content/StyleFlow-Content-Fixed-I2I/scripts/

# %%
# !cd /content/StyleFlow-Content-Fixed-I2I/scripts/ && ls ./

# %%
# !cd /content/StyleFlow-Content-Fixed-I2I/scripts/ && bash test_wikiart.sh

# %%
# !cat /content/StyleFlow-Content-Fixed-I2I/scripts/nohup.out
